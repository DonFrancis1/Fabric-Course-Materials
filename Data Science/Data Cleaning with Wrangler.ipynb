# %%
df = spark.read.format("csv").option("header","true").load("Files/Raw Data.csv")
# df now is a Spark DataFrame containing CSV data from "Files/Raw Data.csv".
display(df)
# Out:
# StatementMeta(, 1cf42cf0-461d-42e9-b1ef-6b9af1a2019e, 61, Finished, Available)
# SynapseWidget(Synapse.DataFrame, cb0ba311-b941-4635-b54f-d3751739b5ec)

# %%
import pandas as pd

df = df.toPandas()
display(df)
# Out:
# StatementMeta(, 1cf42cf0-461d-42e9-b1ef-6b9af1a2019e, 62, Finished, Available)
# SynapseWidget(Synapse.DataFrame, bf72c282-2855-4f79-b13d-bf6d198f53fe)
